# %% [markdown]
# # Problem 2

# %% [markdown]
# Use this notebook to write your code for problem 2. You may reuse your SGD code from last week.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The following function may be useful for loading the necessary data.

# %%
def load_data(filename):
    """
    Function loads data stored in the file filename and returns it as a numpy ndarray.
    
    Inputs:
        filename: given as a string.
        
    Outputs:
        Data contained in the file, returned as a numpy ndarray
    """
    return np.loadtxt(filename, skiprows=1, delimiter=',')

# %%
def loss(X, Y, w):
    '''
    Calculate the log loss function.
    
    Inputs:
        X: A (N, D) shaped numpy array containing the data points.
        Y: A (N, ) shaped numpy array containing the (float) labels of the data points.
        w: A (D, ) shaped numpy array containing the weight vector.
    
    Outputs:
        The loss evaluated with respect to X, Y, and w.
    '''
    
    return -1 * np.sum(np.log(1 / (1 + np.exp(- 1 * Y * np.dot(X, w)))))


def gradient(x, y, w, lam, N):
    '''
    Calculate the gradient of the regularized logistic error with respect to
    a single point (x, y), and using weight vector w.
    
    Inputs:
        x: A (D, ) shaped numpy array containing a single data point.
        y: The float label for the data point.
        w: A (D, ) shaped numpy array containing the weight vector.
        lam: An integer value of the regularization parameter lambda
        N: An integer value of the sample size
        
    Output:
        The gradient of the loss with respect to x, y, and w. 
    '''

    exp = np.exp(-1 * y * np.dot(w, x))
    return exp * (1 + exp) * y * x + (2 * lam / N) * w


def SGD(X, Y, w_start, eta, N_epochs, lam):
    '''
    Perform SGD using dataset (X, Y), initial weight vector w_start,
    learning rate eta, and N_epochs epochs.
    
    Inputs:
        X: A (N, D) shaped numpy array containing the data points.
        Y: A (N, ) shaped numpy array containing the (float) labels of the data points.
        w_start:  A (D, ) shaped numpy array containing the weight vector initialization.
        eta: The step size.
        N_epochs: The number of epochs (iterations) to run SGD.
        lam: An integer value of the regularization parameter lambda.
        
    Outputs:
        w: A (D, ) shaped array containing the final weight vector.
    '''
    
    # N is number of data points
    N = np.size(X, 0)
    w = w_start

    for epoch in range(N_epochs):
        # Go through each point and update
        for i in np.random.permutation(N):
            print('w')
            print(w)
            print('grad')
            print(gradient(X[i], Y[i], w, lam, N))
            w -= eta * gradient(X[i], Y[i], w, lam, N)
        
    return w

# %%
eta = 5e-4
N_epochs = 200

data1 = load_data('data/wine_training1.txt')
X1 = data1[:, 1:]
Y1 = data1[:, 0]

# Normalize X1
X1_mean = np.mean(X1, axis=0)
X1_std = np.std(X1, axis=0)
X1 = (X1 - X1_mean) / X1_std

# Add bias term
X1 = np.insert(X1, 0, 1, axis=1)

D = np.size(X1, 1)

SGD(X1, Y1, np.random.random(D), eta, N_epochs, 0.00025)
# Out:
# 260.7708600908278

# %%
# Problem C
lambdas = [1e-5 * 5 ** i for i in range(15)]

## w1vals = [SGD(asdfasdf, lam) for lam in lambdas]
## train_error = [calc_train_error(w) for w in w1vals]
## test error = 
## norm = [calc_norm(w) for w in w1_vals]
# repeat for w2

w1_vals = [np.random.random(14) for _ in range(15)]
w1_train_errors = [i*100 for i in range(15)]

w2_train_errors = [i*200 for i in range(15)]

# i
plt.figure()
plt.plot(w1_train_errors, lambdas)
plt.plot(w2_train_errors, lambdas)
plt.title('Average training error vs. lambda')
plt.xlabel('Lambda')
plt.ylabel('Average training error')
plt.legend(['wine_training1', 'wine_training2'], loc = 'best')
plt.show()

# ii
plt.figure()
plt.plot(w1_train_errors, lambdas)
plt.plot(w2_train_errors, lambdas)
plt.title('Average test error vs. lambda')
plt.xlabel('Lambda')
plt.ylabel('Average test error')
plt.legend(['wine_training1', 'wine_training2'], loc = 'best')
plt.show()

# iii
plt.figure()
plt.plot(w1_train_errors, lambdas)
plt.plot(w2_train_errors, lambdas)
plt.title('l2 norm of w vs. lambda')
plt.xlabel('Lambda')
plt.ylabel('l2 norm of w')
plt.legend(['wine_training1', 'wine_training2'], loc = 'best')
plt.show()
